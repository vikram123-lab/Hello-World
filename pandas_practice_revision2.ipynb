# %%
import pandas as pd
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('copy.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['Country'] == 'United States'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %%
filt = (df['Country']=="United States")
df[filt]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
df.loc[filt]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
df.loc[filt,'Hobbyist']
# Out:
# 3         No
# 12       Yes
# 21       Yes
# 22       Yes
# 25       Yes
#         ...
# 88818     No
# 88840     No
# 88844    Yes
# 88859     No
# 88877    Yes
# Name: Hobbyist, Length: 20949, dtype: object

# %%
filt = (df['Hobbyist'] == 'Yes') & (df['Country'] == "Ukraine")
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Length: 88883, dtype: bool

# %%
df.loc[filt,'OpenSourcer']
# Out:
# 4                               Once a month or more often
# 327                                Less than once per year
# 519                                                  Never
# 587                                                  Never
# 675                                Less than once per year
#                                ...
# 88160                              Less than once per year
# 88222                              Less than once per year
# 88223                              Less than once per year
# 88242                           Once a month or more often
# 88437    Less than once a month but more than once per ...
# Name: OpenSourcer, Length: 630, dtype: object

# %%
df.loc[~filt,'OpenSourcer']
# Out:
# 0                                                    Never
# 1                                  Less than once per year
# 2                                                    Never
# 3                                                    Never
# 5                                                    Never
#                                ...
# 88878    Less than once a month but more than once per ...
# 88879                                                Never
# 88880                                                Never
# 88881                                                Never
# 88882                              Less than once per year
# Name: OpenSourcer, Length: 88253, dtype: object

# %%
high_salary = (df['ConvertedComp']>7000)

# %%
pd.set_option('display.max_columns',85)

# %%
df.loc[high_salary]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88328       88881                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
# 88330       88883                     I am a developer by profession      Yes
#
# ...

# %%
df.loc[high_salary,['Country','ConvertedComp']]
# Out:
#              Country  ConvertedComp
# 2           Thailand         8820.0
# 3      United States        61000.0
# 5             Canada       366420.0
# 8        New Zealand        95179.0
# 9              India        13293.0
# ...              ...            ...
# 88325  United States       130000.0
# 88326        Finland        82488.0
# 88328        Austria        68745.0
# 88329    Netherlands       588012.0
# 88330         Greece        22915.0
#
# [51905 rows x 2 columns]

# %%
df['LanguageWorkedWith']
filt = df['LanguageWorkedWith'].str.contains('Python',na=False)
df.loc[filt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
